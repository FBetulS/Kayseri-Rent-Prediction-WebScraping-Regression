# %% [markdown]
# # Kayseri Ev Fiyatları Tahmin Projesi
#
# ## Proje Açıklaması
# Bu projede, Kayseri ilindeki ev fiyatlarını tahmin etmek amacıyla web scraping yöntemi kullanarak veriler topladık. Verileri çekmek için Python'un Beautiful Soup kütüphanesini kullandık. Elde edilen veriler üzerinde çeşitli makine öğrenimi modelleri uygulayarak, en iyi sonuçları elde etmeye çalıştık.
#
# Kullanılan başlıca adımlar şunlardır:
# 1. **Veri Toplama**: Web scraping ile Kayseri'deki ev fiyatları ve özellikleri hakkında veriler toplandı.
# 2. **Veri Ön İşleme**: Elde edilen veriler temizlenerek, eksik değerler ve aykırı değerler kontrol edildi.
# 3. **Modelleme**: Farklı makine öğrenimi algoritmaları (özellikle Extra Tree Regressor) kullanılarak modeller oluşturuldu ve sonuçlar değerlendirildi.
# 4. **Sonuçların Değerlendirilmesi**: Elde edilen modellerin performansı R², RMSE ve MAE gibi metriklerle ölçüldü.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

from sklearn.linear_model import LinearRegression, SGDRegressor, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("kayseri_kiralik_ev_data.csv")

# %%
df.head()
# Out:
#    İlan Numarası İlan Oluşturma Tarihi İlan Güncelleme Tarihi   Türü  \
# 0       17087589          28 Mart 2025           28 Mart 2025  Konut
# 1       17082905          27 Mart 2025           27 Mart 2025  Konut
# 2       17081763          27 Mart 2025           27 Mart 2025  Konut
# 3       17078664          26 Mart 2025           26 Mart 2025  Konut
# 4       17076773          26 Mart 2025           26 Mart 2025  Konut
#
#   Kategorisi   Tipi Net Metrekare Brüt Metrekare Oda Sayısı Binanın Yaşı  \
# 0    Kiralık  Daire        125 m²         165 m²        3+1            3
# 1    Kiralık  Daire        230 m²         260 m²        4+1        16-20
# 2    Kiralık  Daire        125 m²         180 m²        3+1        16-20
# 3    Kiralık  Daire         75 m²         100 m²        2+1            2
# 4    Kiralık  Daire        125 m²         170 m²        3+1            3
#
#   Bulunduğu Kat  Binanın Kat Sayısı          Isıtma Tipi Kullanım Durumu  \
# 0         5.Kat                  13  Merkezi (Pay Ölçer)             Boş
# 1        13.Kat                  14     Merkezi Doğalgaz             Boş
# 2         9.Kat                  10     Merkezi Doğalgaz             Boş
# 3         6.Kat                  10  Merkezi (Pay Ölçer)             Boş
# 4         5.Kat                   5       Kombi Doğalgaz             Boş
#
#   Eşya Durumu    Tapu Durumu Site İçerisinde Takas Banyo Sayısı Fiyat Durumu  \
# 0         Boş  Kat Mülkiyeti           Hayır   Yok            1  Genel Fiyat
# 1      Eşyalı  Kat Mülkiyeti           Hayır   Yok            2  Genel Fiyat
# 2         Boş   Kat İrtifakı           Hayır   Yok            2  Genel Fiyat
# 3         Boş  Kat Mülkiyeti           Hayır   Yok            1  Genel Fiyat
# 4         Boş  Kat Mülkiyeti           Hayır   Yok            2  Genel Fiyat
#
#       Fiyat              Lokasyon  \
# 0  17.000TL  Kayseri - Kocasinan
# 1  25.000TL  Kayseri - Melikgazi
# 2  19.000TL  Kayseri - Melikgazi
# 3  11.000TL  Kayseri - Kocasinan
# 4  13.000TL  Kayseri - Melikgazi
#
#                                           İlan Linki Yapı Durumu  Yapı Tipi  \
# 0  https://www.emlakjet.com/ilan/kw-ata-team-kira...         NaN        NaN
# 1  https://www.emlakjet.com/ilan/alpaslan-mahalle...         NaN        NaN
# 2  https://www.emlakjet.com/ilan/aydinlikevler-ma...   İkinci El  Betonarme
# 3  https://www.emlakjet.com/ilan/sehir-hastanesi-...         NaN        NaN
# 4  https://www.emlakjet.com/ilan/melikgazi-bahcel...         NaN        NaN
#
#     Aidat  Depozito Banyo Metrekare Balkon Durumu  Balkon Sayısı  \
# 0     NaN       NaN             NaN           NaN            NaN
# 1     NaN       NaN             NaN           NaN            NaN
# 2  650 TL  38000 TL            7 m²           Var            3.0
# 3     NaN       NaN             NaN           NaN            NaN
# 4     NaN       NaN             NaN           NaN            NaN
#
#                   Balkon Tipi Balkon Metrekare Salon Metrekare WC Sayısı  \
# 0                         NaN              NaN             NaN       NaN
# 1                         NaN              NaN             NaN       NaN
# 2  Açık Balkon, Kapalı Balkon             5 m²           25 m²         2
# 3                         NaN              NaN             NaN       NaN
# 4                         NaN              NaN             NaN       NaN
#
#   WC Metrekare Görüntülü Gezilebilir mi?    Ada  Parsel
# 0          NaN                       NaN    NaN     NaN
# 1          NaN                       NaN    NaN     NaN
# 2         5 m²                     Hayır  736.0    27.0
# 3          NaN                       NaN    NaN     NaN
# 4          NaN                       NaN    NaN     NaN

# %%
df.isnull().sum()
# Out:
# İlan Numarası                  0
# İlan Oluşturma Tarihi          0
# İlan Güncelleme Tarihi         0
# Türü                           0
# Kategorisi                     0
# Tipi                           0
# Net Metrekare                  1
# Brüt Metrekare                 0
# Oda Sayısı                     0
# Binanın Yaşı                   0
# Bulunduğu Kat                 24
# Binanın Kat Sayısı             0
# Isıtma Tipi                    0
# Kullanım Durumu                0
# Eşya Durumu                  285
# Tapu Durumu                    0
# Site İçerisinde                0
# Takas                        203
# Banyo Sayısı                   0
# Fiyat Durumu                   0
# Fiyat                          0
# Lokasyon                       0
# İlan Linki                     0
# Yapı Durumu                  840
# Yapı Tipi                    874
# Aidat                        876
# Depozito                     897
# Banyo Metrekare              959
# Balkon Durumu                908
# Balkon Sayısı                901
# Balkon Tipi                  919
# Balkon Metrekare             956
# Salon Metrekare              955
# WC Sayısı                    901
# WC Metrekare                 963
# Görüntülü Gezilebilir mi?    934
# Ada                          858
# Parsel                       857
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   İlan Numarası              969 non-null    int64
#  1   İlan Oluşturma Tarihi      969 non-null    object
#  2   İlan Güncelleme Tarihi     969 non-null    object
#  3   Türü                       969 non-null    object
#  4   Kategorisi                 969 non-null    object
#  5   Tipi                       969 non-null    object
#  6   Net Metrekare              968 non-null    object
#  7   Brüt Metrekare             969 non-null    object
#  8   Oda Sayısı                 969 non-null    object
#  9   Binanın Yaşı               969 non-null    object
#  10  Bulunduğu Kat              945 non-null    object
#  11  Binanın Kat Sayısı         969 non-null    int64
#  12  Isıtma Tipi                969 non-null    object
#  13  Kullanım Durumu            969 non-null    object
#  14  Eşya Durumu                684 non-null    object
#  15  Tapu Durumu                969 non-null    object
#  16  Site İçerisinde            969 non-null    object
#  17  Takas                      766 non-null    object
#  18  Banyo Sayısı               969 non-null    object
#  19  Fiyat Durumu               969 non-null    object
#  20  Fiyat                      969 non-null    object
#  21  Lokasyon                   969 non-null    object
#  22  İlan Linki                 969 non-null    object
#  23  Yapı Durumu                129 non-null    object
#  24  Yapı Tipi                  95 non-null     object
#  25  Aidat                      93 non-null     object
#  26  Depozito                   72 non-null     object
#  27  Banyo Metrekare            10 non-null     object
#  28  Balkon Durumu              61 non-null     object
#  29  Balkon Sayısı              68 non-null     float64
#  30  Balkon Tipi                50 non-null     object
#  31  Balkon Metrekare           13 non-null     object
#  32  Salon Metrekare            14 non-null     object
#  33  WC Sayısı                  68 non-null     object
#  34  WC Metrekare               6 non-null      object
#  35  Görüntülü Gezilebilir mi?  35 non-null     object
#  36  Ada                        111 non-null    float64
#  37  Parsel                     112 non-null    float64
# dtypes: float64(3), int64(2), object(33)
# memory usage: 287.8+ KB

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100
print(null_percentage)
# Out:
# İlan Numarası                 0.000000
# İlan Oluşturma Tarihi         0.000000
# İlan Güncelleme Tarihi        0.000000
# Türü                          0.000000
# Kategorisi                    0.000000
# Tipi                          0.000000
# Net Metrekare                 0.103199
# Brüt Metrekare                0.000000
# Oda Sayısı                    0.000000
# Binanın Yaşı                  0.000000
# Bulunduğu Kat                 2.476780
# Binanın Kat Sayısı            0.000000
# Isıtma Tipi                   0.000000
# Kullanım Durumu               0.000000
# Eşya Durumu                  29.411765
# Tapu Durumu                   0.000000
# Site İçerisinde               0.000000
# Takas                        20.949432
# Banyo Sayısı                  0.000000
# Fiyat Durumu                  0.000000
# Fiyat                         0.000000
# Lokasyon                      0.000000
# İlan Linki                    0.000000
# Yapı Durumu                  86.687307
# Yapı Tipi                    90.196078
# Aidat                        90.402477
# Depozito                     92.569659
# Banyo Metrekare              98.968008
# Balkon Durumu                93.704850
# Balkon Sayısı                92.982456
# Balkon Tipi                  94.840041
# Balkon Metrekare             98.658411
# Salon Metrekare              98.555212
# WC Sayısı                    92.982456
# WC Metrekare                 99.380805
# Görüntülü Gezilebilir mi?    96.388029
# Ada                          88.544892
# Parsel                       88.441692
# dtype: float64

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100
threshold = 85
df = df.drop(columns=null_percentage[null_percentage > threshold].index)

# %%
df.isnull().sum()
# Out:
# İlan Numarası               0
# İlan Oluşturma Tarihi       0
# İlan Güncelleme Tarihi      0
# Türü                        0
# Kategorisi                  0
# Tipi                        0
# Net Metrekare               1
# Brüt Metrekare              0
# Oda Sayısı                  0
# Binanın Yaşı                0
# Bulunduğu Kat              24
# Binanın Kat Sayısı          0
# Isıtma Tipi                 0
# Kullanım Durumu             0
# Eşya Durumu               285
# Tapu Durumu                 0
# Site İçerisinde             0
# Takas                     203
# Banyo Sayısı                0
# Fiyat Durumu                0
# Fiyat                       0
# Lokasyon                    0
# İlan Linki                  0
# dtype: int64

# %%
df['Türü'].unique()
# Out:
# array(['Konut'], dtype=object)

# %%
df['Türü'].nunique() == 1
# Tüm değerler aynıysa True, değilse False döner
# Out:
# True

# %%
df = df.drop(columns=['Türü'])

# %%
df['Kategorisi'].unique()
# Out:
# array(['Kiralık'], dtype=object)

# %%
df['Kategorisi'].nunique() == 1
# Out:
# True

# %%
df = df.drop(columns=['Kategorisi'])

# %%
df['Tipi'].unique()
# Out:
# array(['Daire', 'Müstakil Ev', 'Villa', 'Köşk', 'Residence', 'Bina'],
#       dtype=object)

# %%
df['Net Metrekare'].unique()
# Out:
# array(['125 m²', '230 m²', '75 m²', '100 m²', '115 m²', '140 m²', '85 m²',
#        '130 m²', '185 m²', '135 m²', '165 m²', '25 m²', '162 m²',
#        '120 m²', '90 m²', '110 m²', '160 m²', '220 m²', '150 m²',
#        '145 m²', '175 m²', '200 m²', '148 m²', '60 m²', '155 m²', '55 m²',
#        '70 m²', '95 m²', '80 m²', '170 m²', '190 m²', '143 m²', '225 m²',
#        '105 m²', '180 m²', '370 m²', '76 m²', '116 m²', '12 m²', '128 m²',
#        '163 m²', '50 m²', '132 m²', '122 m²', '112 m²', '65 m²', '159 m²',
#        '550 m²', '68 m²', '30 m²', '700 m²', '300 m²', '127 m²', '87 m²',
#        '118 m²', '138 m²', '198 m²', '45 m²', '117 m²', '124 m²',
#        '187 m²', '260 m²', '133 m²', nan, '149 m²', '144 m²', '210 m²'],
#       dtype=object)

# %%
df['Net Metrekare'] = df['Net Metrekare'].str.replace(' m²', '', regex=False).astype(float)

# %%
df['Net Metrekare'].unique()
# Out:
# array([125., 230.,  75., 100., 115., 140.,  85., 130., 185., 135., 165.,
#         25., 162., 120.,  90., 110., 160., 220., 150., 145., 175., 200.,
#        148.,  60., 155.,  55.,  70.,  95.,  80., 170., 190., 143., 225.,
#        105., 180., 370.,  76., 116.,  12., 128., 163.,  50., 132., 122.,
#        112.,  65., 159., 550.,  68.,  30., 700., 300., 127.,  87., 118.,
#        138., 198.,  45., 117., 124., 187., 260., 133.,  nan, 149., 144.,
#        210.])

# %%
df['Net Metrekare'].describe()
# Out:
# count    968.000000
# mean     123.913223
# std       40.681865
# min       12.000000
# 25%      100.000000
# 50%      125.000000
# 75%      140.000000
# max      700.000000
# Name: Net Metrekare, dtype: float64

# %%
df['Net Metrekare'].mode()
# Out:
# 0    135.0
# Name: Net Metrekare, dtype: float64

# %%
df['Net Metrekare'].fillna(df['Net Metrekare'].mode()[0], inplace=True)

# %%
df['Brüt Metrekare'].unique()
# Out:
# array(['165 m²', '260 m²', '180 m²', '100 m²', '170 m²', '175 m²',
#        '135 m²', '140 m²', '185 m²', '130 m²', '145 m²', '120 m²',
#        '210 m²', '155 m²', '195 m²', '150 m²', '110 m²', '30 m²',
#        '115 m²', '103 m²', '105 m²', '220 m²', '160 m²', '200 m²',
#        '225 m²', '80 m²', '85 m²', '240 m²', '169 m²', '90 m²', '205 m²',
#        '65 m²', '125 m²', '128 m²', '250 m²', '92 m²', '190 m²', '75 m²',
#        '280 m²', '142 m²', '600 m²', '119 m²', '95 m²', '14 m²', '132 m²',
#        '215 m²', '40 m²', '153 m²', '750 m²', '70 m²', '450 m²', '149 m²',
#        '50 m²', '136 m²', '360 m²', '235 m²', '245 m²', '350 m²',
#        '530 m²', '82 m²', '270 m²', '370 m²', '147 m²'], dtype=object)

# %%
df['Brüt Metrekare'] = df['Brüt Metrekare'].str.replace(' m²', '', regex=False).astype(float)

# %%
df['Oda Sayısı'].unique()
# Out:
# array(['3+1', '4+1', '2+1', '2.5+1', 'Stüdyo', '1+1', '4.5+1', '5+1',
#        '3.5+1', '4+0', '6+1', '1 Oda', '7+2', '3+0', '6+2', '4+2',
#        '9+ Oda', '8+1', '3+2', '8+3', '7+1'], dtype=object)

# %%
df = df[~df['Oda Sayısı'].str.contains('Stüdyo', na=False)]

# %%
import re

# Oda sayısını çıkarma (+, öncesi)
df['Oda'] = df['Oda Sayısı'].str.split('+').str[0].str.strip()

# + içermeyenler için (ör. '1 Oda') düzeltme
mask = ~df['Oda Sayısı'].str.contains('+', regex=False)
df.loc[mask, 'Oda'] = df.loc[mask, 'Oda Sayısı'].str.split().str[0]
df['Oda'] = df['Oda'].astype(float)

# Salon sayısını çıkarma (+, sonrası)
def extract_salon(oda_str):
    if '+' in oda_str:
        right_part = oda_str.split('+')[1].strip()
        return 1 if 'Oda' in right_part else int(re.search(r'\d+', right_part).group(0) if re.search(r'\d', right_part) else 0)
    return 0

df['Salon'] = df['Oda Sayısı'].apply(extract_salon).astype(int)

# %%
df['Oda'].unique()
# Out:
# array([3. , 4. , 2. , 2.5, 1. , 4.5, 5. , 3.5, 6. , 7. , 9. , 8. ])

# %%
df['Salon'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
df['Binanın Yaşı'].unique()
# Out:
# array(['3', '16-20', '2', '4', '0 (Yeni)', '21 Ve Üzeri', '5-10', '11-15',
#        '1'], dtype=object)

# %%
df['Binanın Yaşı'] = df['Binanın Yaşı'].replace('0 (Yeni)', 0)
df['Binanın Yaşı'] = df['Binanın Yaşı'].replace('21 Ve Üzeri', 30)
df['Binanın Yaşı'] = df['Binanın Yaşı'].replace('16-20', '18')
df['Binanın Yaşı'] = df['Binanın Yaşı'].replace('11-15', '13')
df['Binanın Yaşı'] = df['Binanın Yaşı'].replace('5-10', '7')
df['Binanın Yaşı'] = df['Binanın Yaşı'].astype(int)

# %%
df['Binanın Yaşı'].unique()
# Out:
# array([ 3, 18,  2,  4,  0, 30,  7, 13,  1])

# %%
df['Bulunduğu Kat'].unique()
# Out:
# array(['5.Kat', '13.Kat', '9.Kat', '6.Kat', '4.Kat', '2.Kat', '3.Kat',
#        'Yüksek Giriş', '8.Kat', 'Düz Giriş (Zemin)', '10.Kat',
#        'Çatı Katı', 'Kot 4 (-4).Kat', '11.Kat', '1.Kat', '7.Kat',
#        'Müstakil', '12.Kat', '14.Kat', 'Kot 1 (-1).Kat', 'Villa Tipi',
#        '15.Kat', nan, 'Bodrum Kat', 'Kot 3 (-3).Kat', 'Kot 2 (-2).Kat',
#        '20.Kat'], dtype=object)

# %%
kat_mapping = {
    'Müstakil': 1,
    'Villa Tipi': 1,
    'Yüksek Giriş': 1,
    'Düz Giriş (Zemin)': 0,
    'Bodrum Kat': -1,
    'Çatı Katı': 'cati_placeholder',  # Geçici string işaret
    'Zemin': 0
}

# %%
df['Kat'] = (
    df['Bulunduğu Kat']
    .map(kat_mapping)
    .fillna(df['Bulunduğu Kat']) 
)

kot_mask = df['Bulunduğu Kat'].str.contains('Kot', na=False)
df.loc[kot_mask, 'Kat'] = (
    df.loc[kot_mask, 'Bulunduğu Kat']
    .str.extract(r'\((-?\d+)\)')[0]
    .astype(float)
)

# %%
normal_kat_mask = (
    df['Bulunduğu Kat'].str.match(r'^\d+\.?Kat', na=False) &
    ~kot_mask  
)
df.loc[normal_kat_mask, 'Kat'] = (
    df.loc[normal_kat_mask, 'Bulunduğu Kat']
    .str.extract(r'^(\d+)\.?Kat')[0]
    .astype(float)
)

# %%
df['Kat'] = (
    df['Kat']
    .replace('cati_placeholder', np.nan) 
    .apply(pd.to_numeric, errors='coerce')  
)

# %%
df['Kat'].max(skipna=True)
# Out:
# 20.0

# %%
max_kat = 20
df['Kat'] = df['Kat'].fillna(max_kat)

# %%
df['Kat'] = df['Kat'].mask(df['Kat'] < 0, 0).astype(int)

# %%
mode_kat = df['Kat'].mode()[0]
df['Kat'] = df['Kat'].fillna(mode_kat)

# %%
df['Kat'].unique()
# Out:
# array([ 5, 13,  9,  6,  4,  2,  3,  1,  8,  0, 10, 20, 11,  7, 12, 14, 15])

# %%
df['Binanın Kat Sayısı'].unique()
# Out:
# array([13, 14, 10,  5, 11,  6,  2, 12,  3,  9, 15,  4,  8,  7,  1, 18, 21,
#        19], dtype=int64)

# %%
df['Isıtma Tipi'].unique()
# Out:
# array(['Merkezi (Pay Ölçer)', 'Merkezi Doğalgaz', 'Kombi Doğalgaz',
#        'Sobalı', 'Yerden Isıtma', 'Kat Kaloriferi', 'Isıtma Yok',
#        'Doğalgaz Sobalı', 'Merkezi Fueloil'], dtype=object)

# %%
isitma_mapping = {
    # Merkezi Grup
    'Merkezi (Pay Ölçer)': 'Merkezi',
    'Merkezi Doğalgaz': 'Merkezi',
    'Merkezi Fueloil': 'Merkezi',
    
    # Doğalgaz Grup
    'Kombi Doğalgaz': 'Doğalgaz',
    'Kat Kaloriferi': 'Doğalgaz',
    'Doğalgaz Sobalı': 'Doğalgaz',
    
    # Sobalı Grup
    'Sobalı': 'Sobalı',
    'Isıtma Yok': 'Sobalı'
}

df['Isıtma_Kategori'] = df['Isıtma Tipi'].replace(isitma_mapping)

df.loc[df['Isıtma Tipi'] == 'Yerden Isıtma', 'Isıtma_Kategori'] = 'Yerden Isıtma'

# %%
df['Isıtma_Kategori'].unique()
# Out:
# array(['Merkezi', 'Doğalgaz', 'Sobalı', 'Yerden Isıtma'], dtype=object)

# %%
df['Kullanım Durumu'].unique()
# Out:
# array(['Boş', 'Kiracı Oturuyor', 'Mülk Sahibi Oturuyor'], dtype=object)

# %%
df['Eşya Durumu'].unique()
# Out:
# array(['Boş', 'Eşyalı', nan], dtype=object)

# %%
df['Eşya Durumu'].fillna('Boş', inplace=True)

# %%
df['Eşya Durumu'] = df['Eşya Durumu'].map({
    'Boş': 0,
    'Eşyalı': 1
})

# %%
df['Tapu Durumu'].unique()
# Out:
# array(['Kat Mülkiyeti', 'Kat İrtifakı', 'Tapu Kaydı Yok', 'Hisseli Tapu',
#        'Kooperatiften Tapu', 'Müstakil Tapulu', 'Bilinmiyor',
#        'Arsa Tapulu'], dtype=object)

# %%
df['Tapu Durumu'] = df['Tapu Durumu'].map({
    'Tapu Kaydı Yok': 0,
    'Kat Mülkiyeti': 1,
    'Kat İrtifakı': 1,
    'Hisseli Tapu': 1,
    'Kooperatiften Tapu': 1,
    'Müstakil Tapulu': 1,
    'Bilinmiyor': 1,
    'Arsa Tapulu': 1
})

# %%
df['Tapu Durumu'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['Site İçerisinde'].unique()
# Out:
# array(['Hayır', 'Evet'], dtype=object)

# %%
df['Site İçerisinde'] = df['Site İçerisinde'].map({
    'Hayır': 0,
    'Evet': 1
})

# %%
df['Banyo Sayısı'].unique()
# Out:
# array(['1', '2', '3', '4', 'Yok', '5'], dtype=object)

# %%
df['Banyo Sayısı'] = df['Banyo Sayısı'].map({
    'Yok': 0
}).fillna(df['Banyo Sayısı'])

# %%
df['Banyo Sayısı'] = df['Banyo Sayısı'].astype(float)

# %%
df['Takas'].unique()
# Out:
# array(['Yok', nan, 'Var'], dtype=object)

# %%
df['Takas'].fillna('Yok', inplace=True)

# %%
df['Fiyat Durumu'].unique()
# Out:
# array(['Genel Fiyat', 'Birim Fiyat'], dtype=object)

# %%
df['Fiyat'].unique()
# Out:
# array(['17.000TL', '25.000TL', '19.000TL', '11.000TL', '13.000TL',
#        '20.000TL', '10.500TL', '21.000TL', '15.000TL', '11.500TL',
#        '22.000TL', '6.500TL', '10.700TL', '8.000TL', '25.500TL',
#        '10.000TL', '13.500TL', '18.000TL', '6.000TL', '9.000TL',
#        '15.500TL', '18.500TL', '12.000TL', '14.250TL', '7.000TL',
#        '8.500TL', '35.000TL', '14.000TL', '9.500TL', '6.999TL',
#        '12.500TL', '23.000TL', '23.500TL', '30.000TL', '26.000TL',
#        '24.000TL', '16.500TL', '16.000TL', '19.999TL', '13.400TL',
#        '7.500TL', '9.250TL', '12.850TL', '27.500TL', '70.000TL',
#        '12.950TL', '19.500TL', '10.250TL', '27.000TL', '22.500TL',
#        '14.500TL', '12.750TL', '16.750TL', '12.250TL', '8.750TL',
#        '17.500TL', '7.750TL', '50.000TL', '5.000TL', '42.500TL',
#        '90.000TL', '40.000TL', '12.400TL', '13.300TL', '5.500TL',
#        '9.750TL', '28.000TL', '11.250TL', '13.750TL', '75.000TL',
#        '15.250TL', '60.000TL', '29.000TL', '7.250TL', '12.900TL',
#        '58.000TL', '1.400.000TL', '10.750TL', '12.200TL', '6.800TL',
#        '1.200TL', '45.000TL', '15.750TL', '33.000TL', '29.500TL',
#        '7.500.000TL', '14.750TL', '13.900TL', '95.000TL', '8.900TL',
#        '100.000TL', '34.500TL', '11.999TL', '120.000TL', '46.000TL',
#        '65.000TL', '250.000TL', '13.730TL'], dtype=object)

# %%
df['Fiyat'] = (
    df['Fiyat']
    .str.replace('TL', '', regex=False)    
    .str.replace('.', '', regex=False)       
    .str.replace(',', '.', regex=False) 
    .str.strip()                         
)

# %%
df['Fiyat'] = pd.to_numeric(df['Fiyat'], errors='coerce')

# %%
df['Fiyat'].unique()
# Out:
# array([  17000,   25000,   19000,   11000,   13000,   20000,   10500,
#          21000,   15000,   11500,   22000,    6500,   10700,    8000,
#          25500,   10000,   13500,   18000,    6000,    9000,   15500,
#          18500,   12000,   14250,    7000,    8500,   35000,   14000,
#           9500,    6999,   12500,   23000,   23500,   30000,   26000,
#          24000,   16500,   16000,   19999,   13400,    7500,    9250,
#          12850,   27500,   70000,   12950,   19500,   10250,   27000,
#          22500,   14500,   12750,   16750,   12250,    8750,   17500,
#           7750,   50000,    5000,   42500,   90000,   40000,   12400,
#          13300,    5500,    9750,   28000,   11250,   13750,   75000,
#          15250,   60000,   29000,    7250,   12900,   58000, 1400000,
#          10750,   12200,    6800,    1200,   45000,   15750,   33000,
#          29500, 7500000,   14750,   13900,   95000,    8900,  100000,
#          34500,   11999,  120000,   46000,   65000,  250000,   13730],
#       dtype=int64)

# %%
df['Lokasyon'].unique()
# Out:
# array(['Kayseri - Kocasinan ', 'Kayseri - Melikgazi ', 'Kayseri - Talas ',
#        'Kayseri - Develi ', 'Kayseri - İncesu ', 'Kayseri - Yeşilhisar '],
#       dtype=object)

# %%
df['Lokasyon'] = df['Lokasyon'].str.split(' - ').str[1].str.strip()

# %%
df['Lokasyon'].unique()
# Out:
# array(['Kocasinan', 'Melikgazi', 'Talas', 'Develi', 'İncesu',
#        'Yeşilhisar'], dtype=object)

# %%
df = df.drop(columns=['İlan Oluşturma Tarihi', 
                      'İlan Güncelleme Tarihi', 
                      'Kullanım Durumu', 
                      'İlan Linki', 
                      'Fiyat Durumu', 
                      'Oda Sayısı',
                      'İlan Numarası',
                      'Bulunduğu Kat'])

# %%
df.isnull().sum()
# Out:
# Tipi                  0
# Net Metrekare         0
# Brüt Metrekare        0
# Binanın Yaşı          0
# Binanın Kat Sayısı    0
# Isıtma Tipi           0
# Eşya Durumu           0
# Tapu Durumu           0
# Site İçerisinde       0
# Takas                 0
# Banyo Sayısı          0
# Fiyat                 0
# Lokasyon              0
# Oda                   0
# Salon                 0
# Kat                   0
# Isıtma_Kategori       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 965 entries, 0 to 968
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tipi                965 non-null    object
#  1   Net Metrekare       965 non-null    float64
#  2   Brüt Metrekare      965 non-null    float64
#  3   Binanın Yaşı        965 non-null    int32
#  4   Binanın Kat Sayısı  965 non-null    int64
#  5   Isıtma Tipi         965 non-null    object
#  6   Eşya Durumu         965 non-null    int64
#  7   Tapu Durumu         965 non-null    int64
#  8   Site İçerisinde     965 non-null    int64
#  9   Takas               965 non-null    object
#  10  Banyo Sayısı        965 non-null    float64
#  11  Fiyat               965 non-null    int64
#  12  Lokasyon            965 non-null    object
#  13  Oda                 965 non-null    float64
#  14  Salon               965 non-null    int32
#  15  Kat                 965 non-null    int32
#  16  Isıtma_Kategori     965 non-null    object
# dtypes: float64(4), int32(3), int64(5), object(5)
# memory usage: 124.4+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                     Net Metrekare  Brüt Metrekare  Binanın Yaşı  \
# Net Metrekare            1.000000        0.871674      0.075400
# Brüt Metrekare           0.871674        1.000000      0.057206
# Binanın Yaşı             0.075400        0.057206      1.000000
# Binanın Kat Sayısı       0.109984        0.090414     -0.315824
# Eşya Durumu             -0.094365       -0.082277      0.005837
# Tapu Durumu              0.030107        0.024392     -0.006189
# Site İçerisinde          0.126336        0.123858     -0.032841
# Banyo Sayısı             0.501233        0.545519     -0.281576
# Fiyat                    0.043827        0.050416     -0.029504
# Oda                      0.768159        0.772286      0.024153
# Salon                    0.183077        0.344889      0.087504
# Kat                      0.298899        0.352597     -0.138563
#
#                     Binanın Kat Sayısı  Eşya Durumu  Tapu Durumu  \
# Net Metrekare                 0.109984    -0.094365     0.030107
# Brüt Metrekare                0.090414    -0.082277     0.024392
# Binanın Yaşı                 -0.315824     0.005837    -0.006189
# Binanın Kat Sayısı            1.000000    -0.014201     0.010019
# Eşya Durumu                  -0.014201     1.000000     0.047341
# Tapu Durumu                   0.010019     0.047341     1.000000
# Site İçerisinde               0.148955     0.010433    -0.005861
# Banyo Sayısı                  0.210159    -0.107766     0.026673
# Fiyat                        -0.057582    -0.007038     0.009021
# Oda                           0.114833    -0.189147    -0.012177
# Salon                        -0.080351     0.031068    -0.002348
# Kat                           0.278355     0.026426     0.032939
#
#                     Site İçerisinde  Banyo Sayısı     Fiyat       Oda  \
# Net Metrekare              0.126336      0.501233  0.043827  0.768159
# Brüt Metrekare             0.123858      0.545519  0.050416  0.772286
# Binanın Yaşı              -0.032841     -0.281576 -0.029504  0.024153
# Binanın Kat Sayısı         0.148955      0.210159 -0.057582  0.114833
# Eşya Durumu                0.010433     -0.107766 -0.007038 -0.189147
# Tapu Durumu               -0.005861      0.026673  0.009021 -0.012177
# Site İçerisinde            1.000000      0.123688 -0.001438  0.092480
# Banyo Sayısı               0.123688      1.000000  0.047633  0.536095
# Fiyat                     -0.001438      0.047633  1.000000  0.084923
# Oda                        0.092480      0.536095  0.084923  1.000000
# Salon                      0.005031      0.172290  0.011640  0.187139
# Kat                        0.002990      0.285901  0.102350  0.288852
#
#                        Salon       Kat
# Net Metrekare       0.183077  0.298899
# Brüt Metrekare      0.344889  0.352597
# Binanın Yaşı        0.087504 -0.138563
# Binanın Kat Sayısı -0.080351  0.278355
# Eşya Durumu         0.031068  0.026426
# Tapu Durumu        -0.002348  0.032939
# Site İçerisinde     0.005031  0.002990
# Banyo Sayısı        0.172290  0.285901
# Fiyat               0.011640  0.102350
# Oda                 0.187139  0.288852
# Salon               1.000000  0.206158
# Kat                 0.206158  1.000000

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    Net Metrekare  Brüt Metrekare  Binanın Yaşı  Binanın Kat Sayısı  \
# 0          125.0           165.0             3                  13
# 1          230.0           260.0            18                  14
# 2          125.0           180.0            18                  10
# 3           75.0           100.0             2                  10
# 4          125.0           170.0             3                   5
#
#    Eşya Durumu  Tapu Durumu  Site İçerisinde  Banyo Sayısı  Fiyat  Oda  Salon  \
# 0            0            1                0           1.0  17000  3.0      1
# 1            1            1                0           2.0  25000  4.0      1
# 2            0            1                0           2.0  19000  3.0      1
# 3            0            1                0           1.0  11000  2.0      1
# 4            0            1                0           2.0  13000  3.0      1
#
#    Kat  Tipi_Daire  Tipi_Köşk  Tipi_Müstakil Ev  Tipi_Residence  Tipi_Villa  \
# 0    5        True      False             False           False       False
# 1   13        True      False             False           False       False
# 2    9        True      False             False           False       False
# 3    6        True      False             False           False       False
# 4    5        True      False             False           False       False
#
#    Isıtma Tipi_Isıtma Yok  Isıtma Tipi_Kat Kaloriferi  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                   False                       False
#
#    Isıtma Tipi_Kombi Doğalgaz  Isıtma Tipi_Merkezi (Pay Ölçer)  \
# 0                       False                             True
# 1                       False                            False
# 2                       False                            False
# 3                       False                             True
# 4                        True                            False
#
#    Isıtma Tipi_Merkezi Doğalgaz  Isıtma Tipi_Merkezi Fueloil  \
# 0                         False                        False
# 1                          True                        False
# 2                          True                        False
# 3                         False                        False
# 4                         False                        False
#
#    Isıtma Tipi_Sobalı  Isıtma Tipi_Yerden Isıtma  Takas_Yok  \
# 0               False                      False       True
# 1               False                      False       True
# 2               False                      False       True
# 3               False                      False       True
# 4               False                      False       True
#
#    Lokasyon_Kocasinan  Lokasyon_Melikgazi  Lokasyon_Talas  \
# 0                True               False           False
# 1               False                True           False
# 2               False                True           False
# 3                True               False           False
# 4               False                True           False
#
#    Lokasyon_Yeşilhisar  Lokasyon_İncesu  Isıtma_Kategori_Merkezi  \
# 0                False            False                     True
# 1                False            False                     True
# 2                False            False                     True
# 3                False            False                     True
# 4                False            False                    False
#
#    Isıtma_Kategori_Sobalı  Isıtma_Kategori_Yerden Isıtma
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False

# %%
df.corr()
# Out:
#                                  Net Metrekare  Brüt Metrekare  Binanın Yaşı  \
# Net Metrekare                         1.000000        0.871674      0.075400
# Brüt Metrekare                        0.871674        1.000000      0.057206
# Binanın Yaşı                          0.075400        0.057206      1.000000
# Binanın Kat Sayısı                    0.109984        0.090414     -0.315824
# Eşya Durumu                          -0.094365       -0.082277      0.005837
# Tapu Durumu                           0.030107        0.024392     -0.006189
# Site İçerisinde                       0.126336        0.123858     -0.032841
# Banyo Sayısı                          0.501233        0.545519     -0.281576
# Fiyat                                 0.043827        0.050416     -0.029504
# Oda                                   0.768159        0.772286      0.024153
# Salon                                 0.183077        0.344889      0.087504
# Kat                                   0.298899        0.352597     -0.138563
# Tipi_Daire                           -0.296792       -0.400305     -0.031242
# Tipi_Köşk                             0.458562        0.357493      0.064470
# Tipi_Müstakil Ev                      0.075339        0.101477      0.101618
# Tipi_Residence                       -0.112831       -0.098915     -0.017465
# Tipi_Villa                            0.337583        0.498979     -0.044271
# Isıtma Tipi_Isıtma Yok               -0.035223       -0.030995      0.064470
# Isıtma Tipi_Kat Kaloriferi            0.019481        0.011889     -0.020411
# Isıtma Tipi_Kombi Doğalgaz           -0.012438       -0.013030      0.311879
# Isıtma Tipi_Merkezi (Pay Ölçer)      -0.048998       -0.028896     -0.478362
# Isıtma Tipi_Merkezi Doğalgaz          0.050060        0.027752      0.103141
# Isıtma Tipi_Merkezi Fueloil           0.004599       -0.010077     -0.025031
# Isıtma Tipi_Sobalı                    0.005483        0.020355      0.273233
# Isıtma Tipi_Yerden Isıtma             0.095429        0.087883     -0.054896
# Takas_Yok                             0.003366        0.010077     -0.008117
# Lokasyon_Kocasinan                    0.007484        0.023468      0.067092
# Lokasyon_Melikgazi                    0.123350        0.125677      0.080736
# Lokasyon_Talas                       -0.083286       -0.079010     -0.146211
# Lokasyon_Yeşilhisar                  -0.046625       -0.050116      0.129140
# Lokasyon_İncesu                      -0.063372       -0.058923     -0.031906
# Isıtma_Kategori_Merkezi              -0.000219       -0.002738     -0.385111
# Isıtma_Kategori_Sobalı               -0.002414        0.013040      0.281006
# Isıtma_Kategori_Yerden Isıtma         0.095429        0.087883     -0.054896
#
#                                  Binanın Kat Sayısı  Eşya Durumu  Tapu Durumu  \
# Net Metrekare                              0.109984    -0.094365     0.030107
# Brüt Metrekare                             0.090414    -0.082277     0.024392
# Binanın Yaşı                              -0.315824     0.005837    -0.006189
# Binanın Kat Sayısı                         1.000000    -0.014201     0.010019
# Eşya Durumu                               -0.014201     1.000000     0.047341
# Tapu Durumu                                0.010019     0.047341     1.000000
# Site İçerisinde                            0.148955     0.010433    -0.005861
# Banyo Sayısı                               0.210159    -0.107766     0.026673
# Fiyat                                     -0.057582    -0.007038     0.009021
# Oda                                        0.114833    -0.189147    -0.012177
# Salon                                     -0.080351     0.031068    -0.002348
# Kat                                        0.278355     0.026426     0.032939
# Tipi_Daire                                 0.244212    -0.016915    -0.028706
# Tipi_Köşk                                 -0.054591    -0.009350     0.005253
# Tipi_Müstakil Ev                          -0.173443     0.046736     0.016688
# Tipi_Residence                            -0.013919     0.032961     0.011769
# Tipi_Villa                                -0.168257    -0.031172     0.017512
# Isıtma Tipi_Isıtma Yok                    -0.031913    -0.009350    -0.197495
# Isıtma Tipi_Kat Kaloriferi                 0.066995    -0.016211     0.009107
# Isıtma Tipi_Kombi Doğalgaz                -0.605675     0.009673    -0.019607
# Isıtma Tipi_Merkezi (Pay Ölçer)            0.379756    -0.044555    -0.015909
# Isıtma Tipi_Merkezi Doğalgaz               0.280320     0.047531     0.039068
# Isıtma Tipi_Merkezi Fueloil                0.043679    -0.009350     0.005253
# Isıtma Tipi_Sobalı                        -0.224386    -0.015063     0.023725
# Isıtma Tipi_Yerden Isıtma                 -0.042226    -0.016211     0.009107
# Takas_Yok                                 -0.021001     0.009350    -0.005253
# Lokasyon_Kocasinan                        -0.117486    -0.054619     0.040054
# Lokasyon_Melikgazi                         0.018011    -0.071178    -0.136956
# Lokasyon_Talas                             0.345388     0.156244     0.078458
# Lokasyon_Yeşilhisar                       -0.105566    -0.018729     0.010521
# Lokasyon_İncesu                           -0.085915    -0.016211     0.009107
# Isıtma_Kategori_Merkezi                    0.662615     0.000850     0.022562
# Isıtma_Kategori_Sobalı                    -0.226132    -0.016769    -0.020386
# Isıtma_Kategori_Yerden Isıtma             -0.042226    -0.016211     0.009107
#
#                                  Site İçerisinde  Banyo Sayısı     Fiyat  \
# Net Metrekare                           0.126336      0.501233  0.043827
# Brüt Metrekare                          0.123858      0.545519  0.050416
# Binanın Yaşı                           -0.032841     -0.281576 -0.029504
# Binanın Kat Sayısı                      0.148955      0.210159 -0.057582
# Eşya Durumu                             0.010433     -0.107766 -0.007038
# Tapu Durumu                            -0.005861      0.026673  0.009021
# Site İçerisinde                         1.000000      0.123688 -0.001438
# Banyo Sayısı                            0.123688      1.000000  0.047633
# Fiyat                                  -0.001438      0.047633  1.000000
# Oda                                     0.092480      0.536095  0.084923
# Salon                                   0.005031      0.172290  0.011640
# Kat                                     0.002990      0.285901  0.102350
# Tipi_Daire                              0.042013     -0.199364 -0.192560
# Tipi_Köşk                              -0.011254      0.088375  0.004641
# Tipi_Müstakil Ev                       -0.035756     -0.002569 -0.002466
# Tipi_Residence                         -0.025217     -0.051771 -0.004349
# Tipi_Villa                             -0.006172      0.328426  0.314229
# Isıtma Tipi_Isıtma Yok                 -0.011254     -0.023105 -0.001925
# Isıtma Tipi_Kat Kaloriferi             -0.019513     -0.007845 -0.002806
# Isıtma Tipi_Kombi Doğalgaz             -0.086687     -0.135851 -0.026633
# Isıtma Tipi_Merkezi (Pay Ölçer)         0.054972      0.178781 -0.024541
# Isıtma Tipi_Merkezi Doğalgaz            0.045709     -0.032362  0.042111
# Isıtma Tipi_Merkezi Fueloil            -0.011254     -0.023105 -0.001400
# Isıtma Tipi_Sobalı                     -0.050833     -0.079183  0.031579
# Isıtma Tipi_Yerden Isıtma               0.040264      0.088799  0.006718
# Takas_Yok                              -0.092176      0.023105  0.001433
# Lokasyon_Kocasinan                      0.000223      0.005426 -0.014249
# Lokasyon_Melikgazi                     -0.003742      0.097271  0.037798
# Lokasyon_Talas                          0.061635     -0.099992 -0.016017
# Lokasyon_Yeşilhisar                    -0.022543     -0.046281 -0.004711
# Lokasyon_İncesu                         0.040264     -0.040060 -0.004002
# Isıtma_Kategori_Merkezi                 0.099752      0.147784  0.016349
# Isıtma_Kategori_Sobalı                 -0.052116     -0.082411  0.030409
# Isıtma_Kategori_Yerden Isıtma           0.040264      0.088799  0.006718
#
#                                       Oda     Salon       Kat  Tipi_Daire  \
# Net Metrekare                    0.768159  0.183077  0.298899   -0.296792
# Brüt Metrekare                   0.772286  0.344889  0.352597   -0.400305
# Binanın Yaşı                     0.024153  0.087504 -0.138563   -0.031242
# Binanın Kat Sayısı               0.114833 -0.080351  0.278355    0.244212
# Eşya Durumu                     -0.189147  0.031068  0.026426   -0.016915
# Tapu Durumu                     -0.012177 -0.002348  0.032939   -0.028706
# Site İçerisinde                  0.092480  0.005031  0.002990    0.042013
# Banyo Sayısı                     0.536095  0.172290  0.285901   -0.199364
# Fiyat                            0.084923  0.011640  0.102350   -0.192560
# Oda                              1.000000  0.187139  0.288852   -0.261374
# Salon                            0.187139  1.000000  0.206158   -0.339858
# Kat                              0.288852  0.206158  1.000000   -0.444477
# Tipi_Daire                      -0.261374 -0.339858 -0.444477    1.000000
# Tipi_Köşk                        0.257730  0.000464  0.099454   -0.182979
# Tipi_Müstakil Ev                 0.053305  0.285822  0.315978   -0.581349
# Tipi_Residence                  -0.123431  0.001039 -0.012692   -0.410004
# Tipi_Villa                       0.372398  0.272804  0.331574   -0.610044
# Isıtma Tipi_Isıtma Yok          -0.038177  0.000464 -0.019680    0.005669
# Isıtma Tipi_Kat Kaloriferi       0.007102  0.000804  0.010430    0.009830
# Isıtma Tipi_Kombi Doğalgaz      -0.028114  0.056453 -0.178628   -0.041735
# Isıtma Tipi_Merkezi (Pay Ölçer)  0.008649 -0.079716  0.087910    0.117423
# Isıtma Tipi_Merkezi Doğalgaz     0.004606 -0.021436  0.051399    0.026431
# Isıtma Tipi_Merkezi Fueloil      0.004096  0.000464  0.001343    0.005669
# Isıtma Tipi_Sobalı              -0.010141  0.103158  0.037722   -0.230022
# Isıtma Tipi_Yerden Isıtma        0.068180  0.000804  0.148136   -0.208229
# Takas_Yok                       -0.004096 -0.000464  0.012672   -0.005669
# Lokasyon_Kocasinan               0.065521 -0.098837 -0.126270    0.053694
# Lokasyon_Melikgazi               0.107633  0.100864  0.075809   -0.083992
# Lokasyon_Talas                  -0.138143  0.024938  0.112209    0.002565
# Lokasyon_Yeşilhisar             -0.055303  0.000929 -0.060478    0.011356
# Lokasyon_İncesu                 -0.066193  0.000804 -0.062474    0.009830
# Isıtma_Kategori_Merkezi          0.013558 -0.101745  0.139558    0.145258
# Isıtma_Kategori_Sobalı          -0.018320  0.100827  0.032492   -0.223347
# Isıtma_Kategori_Yerden Isıtma    0.068180  0.000804  0.148136   -0.208229
#
#                                  Tipi_Köşk  Tipi_Müstakil Ev  Tipi_Residence  \
# Net Metrekare                     0.458562          0.075339       -0.112831
# Brüt Metrekare                    0.357493          0.101477       -0.098915
# Binanın Yaşı                      0.064470          0.101618       -0.017465
# Binanın Kat Sayısı               -0.054591         -0.173443       -0.013919
# Eşya Durumu                      -0.009350          0.046736        0.032961
# Tapu Durumu                       0.005253          0.016688        0.011769
# Site İçerisinde                  -0.011254         -0.035756       -0.025217
# Banyo Sayısı                      0.088375         -0.002569       -0.051771
# Fiyat                             0.004641         -0.002466       -0.004349
# Oda                               0.257730          0.053305       -0.123431
# Salon                             0.000464          0.285822        0.001039
# Kat                               0.099454          0.315978       -0.012692
# Tipi_Daire                       -0.182979         -0.581349       -0.410004
# Tipi_Köşk                         1.000000         -0.003296       -0.002324
# Tipi_Müstakil Ev                 -0.003296          1.000000       -0.007385
# Tipi_Residence                   -0.002324         -0.007385        1.000000
# Tipi_Villa                       -0.003458         -0.010988       -0.007749
# Isıtma Tipi_Isıtma Yok           -0.001037         -0.003296       -0.002324
# Isıtma Tipi_Kat Kaloriferi       -0.001799         -0.005714       -0.004030
# Isıtma Tipi_Kombi Doğalgaz        0.048657         -0.001037       -0.047771
# Isıtma Tipi_Merkezi (Pay Ölçer)  -0.023809         -0.075646       -0.053350
# Isıtma Tipi_Merkezi Doğalgaz     -0.021633         -0.068730        0.107448
# Isıtma Tipi_Merkezi Fueloil      -0.001037         -0.003296       -0.002324
# Isıtma Tipi_Sobalı               -0.004686          0.416082       -0.010499
# Isıtma Tipi_Yerden Isıtma        -0.001799         -0.005714       -0.004030
# Takas_Yok                         0.001037          0.003296        0.002324
# Lokasyon_Kocasinan               -0.021790         -0.003084       -0.048825
# Lokasyon_Melikgazi               -0.024026          0.030423       -0.023719
# Lokasyon_Talas                    0.056135         -0.011300        0.092344
# Lokasyon_Yeşilhisar              -0.002078         -0.006602       -0.004656
# Lokasyon_İncesu                  -0.001799         -0.005714       -0.004030
# Isıtma_Kategori_Merkezi          -0.045408         -0.144266        0.051190
# Isıtma_Kategori_Sobalı           -0.004804          0.405543       -0.010764
# Isıtma_Kategori_Yerden Isıtma    -0.001799         -0.005714       -0.004030
#
#                                  Tipi_Villa  Isıtma Tipi_Isıtma Yok  \
# Net Metrekare                      0.337583               -0.035223
# Brüt Metrekare                     0.498979               -0.030995
# Binanın Yaşı                      -0.044271                0.064470
# Binanın Kat Sayısı                -0.168257               -0.031913
# Eşya Durumu                       -0.031172               -0.009350
# Tapu Durumu                        0.017512               -0.197495
# Site İçerisinde                   -0.006172               -0.011254
# Banyo Sayısı                       0.328426               -0.023105
# Fiyat                              0.314229               -0.001925
# Oda                                0.372398               -0.038177
# Salon                              0.272804                0.000464
# Kat                                0.331574               -0.019680
# Tipi_Daire                        -0.610044                0.005669
# Tipi_Köşk                         -0.003458               -0.001037
# Tipi_Müstakil Ev                  -0.010988               -0.003296
# Tipi_Residence                    -0.007749               -0.002324
# Tipi_Villa                         1.000000               -0.003458
# Isıtma Tipi_Isıtma Yok            -0.003458                1.000000
# Isıtma Tipi_Kat Kaloriferi        -0.005996               -0.001799
# Isıtma Tipi_Kombi Doğalgaz         0.098595               -0.021319
# Isıtma Tipi_Merkezi (Pay Ölçer)   -0.079379               -0.023809
# Isıtma Tipi_Merkezi Doğalgaz      -0.051032               -0.021633
# Isıtma Tipi_Merkezi Fueloil       -0.003458               -0.001037
# Isıtma Tipi_Sobalı                -0.015621               -0.004686
# Isıtma Tipi_Yerden Isıtma          0.344706               -0.001799
# Takas_Yok                          0.003458                0.001037
# Lokasyon_Kocasinan                -0.030580                0.047607
# Lokasyon_Melikgazi                 0.103213               -0.024026
# Lokasyon_Talas                    -0.061610               -0.018480
# Lokasyon_Yeşilhisar               -0.006928               -0.002078
# Lokasyon_İncesu                   -0.005996               -0.001799
# Isıtma_Kategori_Merkezi           -0.130700               -0.045408
# Isıtma_Kategori_Sobalı            -0.016016                0.215942
# Isıtma_Kategori_Yerden Isıtma      0.344706               -0.001799
#
#                                  Isıtma Tipi_Kat Kaloriferi  \
# Net Metrekare                                      0.019481
# Brüt Metrekare                                     0.011889
# Binanın Yaşı                                      -0.020411
# Binanın Kat Sayısı                                 0.066995
# Eşya Durumu                                       -0.016211
# Tapu Durumu                                        0.009107
# Site İçerisinde                                   -0.019513
# Banyo Sayısı                                      -0.007845
# Fiyat                                             -0.002806
# Oda                                                0.007102
# Salon                                              0.000804
# Kat                                                0.010430
# Tipi_Daire                                         0.009830
# Tipi_Köşk                                         -0.001799
# Tipi_Müstakil Ev                                  -0.005714
# Tipi_Residence                                    -0.004030
# Tipi_Villa                                        -0.005996
# Isıtma Tipi_Isıtma Yok                            -0.001799
# Isıtma Tipi_Kat Kaloriferi                         1.000000
# Isıtma Tipi_Kombi Doğalgaz                        -0.036965
# Isıtma Tipi_Merkezi (Pay Ölçer)                   -0.041282
# Isıtma Tipi_Merkezi Doğalgaz                      -0.037508
# Isıtma Tipi_Merkezi Fueloil                       -0.001799
# Isıtma Tipi_Sobalı                                -0.008124
# Isıtma Tipi_Yerden Isıtma                         -0.003119
# Takas_Yok                                          0.001799
# Lokasyon_Kocasinan                                 0.002327
# Lokasyon_Melikgazi                                -0.041657
# Lokasyon_Talas                                     0.054206
# Lokasyon_Yeşilhisar                               -0.003603
# Lokasyon_İncesu                                   -0.003119
# Isıtma_Kategori_Merkezi                           -0.078730
# Isıtma_Kategori_Sobalı                            -0.008329
# Isıtma_Kategori_Yerden Isıtma                     -0.003119
#
#                                  Isıtma Tipi_Kombi Doğalgaz  \
# Net Metrekare                                     -0.012438
# Brüt Metrekare                                    -0.013030
# Binanın Yaşı                                       0.311879
# Binanın Kat Sayısı                                -0.605675
# Eşya Durumu                                        0.009673
# Tapu Durumu                                       -0.019607
# Site İçerisinde                                   -0.086687
# Banyo Sayısı                                      -0.135851
# Fiyat                                             -0.026633
# Oda                                               -0.028114
# Salon                                              0.056453
# Kat                                               -0.178628
# Tipi_Daire                                        -0.041735
# Tipi_Köşk                                          0.048657
# Tipi_Müstakil Ev                                  -0.001037
# Tipi_Residence                                    -0.047771
# Tipi_Villa                                         0.098595
# Isıtma Tipi_Isıtma Yok                            -0.021319
# Isıtma Tipi_Kat Kaloriferi                        -0.036965
# Isıtma Tipi_Kombi Doğalgaz                         1.000000
# Isıtma Tipi_Merkezi (Pay Ölçer)                   -0.489325
# Isıtma Tipi_Merkezi Doğalgaz                      -0.444593
# Isıtma Tipi_Merkezi Fueloil                       -0.021319
# Isıtma Tipi_Sobalı                                -0.096297
# Isıtma Tipi_Yerden Isıtma                         -0.036965
# Takas_Yok                                          0.021319
# Lokasyon_Kocasinan                                 0.046993
# Lokasyon_Melikgazi                                -0.038093
# Lokasyon_Talas                                    -0.233746
# Lokasyon_Yeşilhisar                                0.027381
# Lokasyon_İncesu                                   -0.036965
# Isıtma_Kategori_Merkezi                           -0.933208
# Isıtma_Kategori_Sobalı                            -0.098727
# Isıtma_Kategori_Yerden Isıtma                     -0.036965
#
#                                  Isıtma Tipi_Merkezi (Pay Ölçer)  \
# Net Metrekare                                          -0.048998
# Brüt Metrekare                                         -0.028896
# Binanın Yaşı                                           -0.478362
# Binanın Kat Sayısı                                      0.379756
# Eşya Durumu                                            -0.044555
# Tapu Durumu                                            -0.015909
# Site İçerisinde                                         0.054972
# Banyo Sayısı                                            0.178781
# Fiyat                                                  -0.024541
# Oda                                                     0.008649
# Salon                                                  -0.079716
# Kat                                                     0.087910
# Tipi_Daire                                              0.117423
# Tipi_Köşk                                              -0.023809
# Tipi_Müstakil Ev                                       -0.075646
# Tipi_Residence                                         -0.053350
# Tipi_Villa                                             -0.079379
# Isıtma Tipi_Isıtma Yok                                 -0.023809
# Isıtma Tipi_Kat Kaloriferi                             -0.041282
# Isıtma Tipi_Kombi Doğalgaz                             -0.489325
# Isıtma Tipi_Merkezi (Pay Ölçer)                         1.000000
# Isıtma Tipi_Merkezi Doğalgaz                           -0.496518
# Isıtma Tipi_Merkezi Fueloil                            -0.023809
# Isıtma Tipi_Sobalı                                     -0.107543
# Isıtma Tipi_Yerden Isıtma                              -0.041282
# Takas_Yok                                               0.023809
# Lokasyon_Kocasinan                                      0.069735
# Lokasyon_Melikgazi                                     -0.026741
# Lokasyon_Talas                                          0.083092
# Lokasyon_Yeşilhisar                                    -0.047693
# Lokasyon_İncesu                                         0.036601
# Isıtma_Kategori_Merkezi                                 0.524347
# Isıtma_Kategori_Sobalı                                 -0.110258
# Isıtma_Kategori_Yerden Isıtma                          -0.041282
#
#                                  Isıtma Tipi_Merkezi Doğalgaz  \
# Net Metrekare                                        0.050060
# Brüt Metrekare                                       0.027752
# Binanın Yaşı                                         0.103141
# Binanın Kat Sayısı                                   0.280320
# Eşya Durumu                                          0.047531
# Tapu Durumu                                          0.039068
# Site İçerisinde                                      0.045709
# Banyo Sayısı                                        -0.032362
# Fiyat                                                0.042111
# Oda                                                  0.004606
# Salon                                               -0.021436
# Kat                                                  0.051399
# Tipi_Daire                                           0.026431
# Tipi_Köşk                                           -0.021633
# Tipi_Müstakil Ev                                    -0.068730
# Tipi_Residence                                       0.107448
# Tipi_Villa                                          -0.051032
# Isıtma Tipi_Isıtma Yok                              -0.021633
# Isıtma Tipi_Kat Kaloriferi                          -0.037508
# Isıtma Tipi_Kombi Doğalgaz                          -0.444593
# Isıtma Tipi_Merkezi (Pay Ölçer)                     -0.496518
# Isıtma Tipi_Merkezi Doğalgaz                         1.000000
# Isıtma Tipi_Merkezi Fueloil                         -0.021633
# Isıtma Tipi_Sobalı                                  -0.097712
# Isıtma Tipi_Yerden Isıtma                           -0.037508
# Takas_Yok                                           -0.047953
# Lokasyon_Kocasinan                                  -0.121549
# Lokasyon_Melikgazi                                   0.068886
# Lokasyon_Talas                                       0.154041
# Lokasyon_Yeşilhisar                                 -0.043333
# Lokasyon_İncesu                                      0.002709
# Isıtma_Kategori_Merkezi                              0.476413
# Isıtma_Kategori_Sobalı                              -0.100178
# Isıtma_Kategori_Yerden Isıtma                       -0.037508
#
#                                  Isıtma Tipi_Merkezi Fueloil  \
# Net Metrekare                                       0.004599
# Brüt Metrekare                                     -0.010077
# Binanın Yaşı                                       -0.025031
# Binanın Kat Sayısı                                  0.043679
# Eşya Durumu                                        -0.009350
# Tapu Durumu                                         0.005253
# Site İçerisinde                                    -0.011254
# Banyo Sayısı                                       -0.023105
# Fiyat                                              -0.001400
# Oda                                                 0.004096
# Salon                                               0.000464
# Kat                                                 0.001343
# Tipi_Daire                                          0.005669
# Tipi_Köşk                                          -0.001037
# Tipi_Müstakil Ev                                   -0.003296
# Tipi_Residence                                     -0.002324
# Tipi_Villa                                         -0.003458
# Isıtma Tipi_Isıtma Yok                             -0.001037
# Isıtma Tipi_Kat Kaloriferi                         -0.001799
# Isıtma Tipi_Kombi Doğalgaz                         -0.021319
# Isıtma Tipi_Merkezi (Pay Ölçer)                    -0.023809
# Isıtma Tipi_Merkezi Doğalgaz                       -0.021633
# Isıtma Tipi_Merkezi Fueloil                         1.000000
# Isıtma Tipi_Sobalı                                 -0.004686
# Isıtma Tipi_Yerden Isıtma                          -0.001799
# Takas_Yok                                           0.001037
# Lokasyon_Kocasinan                                 -0.021790
# Lokasyon_Melikgazi                                 -0.024026
# Lokasyon_Talas                                      0.056135
# Lokasyon_Yeşilhisar                                -0.002078
# Lokasyon_İncesu                                    -0.001799
# Isıtma_Kategori_Merkezi                             0.022845
# Isıtma_Kategori_Sobalı                             -0.004804
# Isıtma_Kategori_Yerden Isıtma                      -0.001799
#
#                                  Isıtma Tipi_Sobalı  \
# Net Metrekare                              0.005483
# Brüt Metrekare                             0.020355
# Binanın Yaşı                               0.273233
# Binanın Kat Sayısı                        -0.224386
# Eşya Durumu                               -0.015063
# Tapu Durumu                                0.023725
# Site İçerisinde                           -0.050833
# Banyo Sayısı                              -0.079183
# Fiyat                                      0.031579
# Oda                                       -0.010141
# Salon                                      0.103158
# Kat                                        0.037722
# Tipi_Daire                                -0.230022
# Tipi_Köşk                                 -0.004686
# Tipi_Müstakil Ev                           0.416082
# Tipi_Residence                            -0.010499
# Tipi_Villa                                -0.015621
# Isıtma Tipi_Isıtma Yok                    -0.004686
# Isıtma Tipi_Kat Kaloriferi                -0.008124
# Isıtma Tipi_Kombi Doğalgaz                -0.096297
# Isıtma Tipi_Merkezi (Pay Ölçer)           -0.107543
# Isıtma Tipi_Merkezi Doğalgaz              -0.097712
# Isıtma Tipi_Merkezi Fueloil               -0.004686
# Isıtma Tipi_Sobalı                         1.000000
# Isıtma Tipi_Yerden Isıtma                 -0.008124
# Takas_Yok                                  0.004686
# Lokasyon_Kocasinan                         0.026960
# Lokasyon_Melikgazi                        -0.017458
# Lokasyon_Talas                            -0.049768
# Lokasyon_Yeşilhisar                        0.217045
# Lokasyon_İncesu                           -0.008124
# Isıtma_Kategori_Merkezi                   -0.205100
# Isıtma_Kategori_Sobalı                     0.975384
# Isıtma_Kategori_Yerden Isıtma             -0.008124
#
#                                  Isıtma Tipi_Yerden Isıtma  Takas_Yok  \
# Net Metrekare                                     0.095429   0.003366
# Brüt Metrekare                                    0.087883   0.010077
# Binanın Yaşı                                     -0.054896  -0.008117
# Binanın Kat Sayısı                               -0.042226  -0.021001
# Eşya Durumu                                      -0.016211   0.009350
# Tapu Durumu                                       0.009107  -0.005253
# Site İçerisinde                                   0.040264  -0.092176
# Banyo Sayısı                                      0.088799   0.023105
# Fiyat                                             0.006718   0.001433
# Oda                                               0.068180  -0.004096
# Salon                                             0.000804  -0.000464
# Kat                                               0.148136   0.012672
# Tipi_Daire                                       -0.208229  -0.005669
# Tipi_Köşk                                        -0.001799   0.001037
# Tipi_Müstakil Ev                                 -0.005714   0.003296
# Tipi_Residence                                   -0.004030   0.002324
# Tipi_Villa                                        0.344706   0.003458
# Isıtma Tipi_Isıtma Yok                           -0.001799   0.001037
# Isıtma Tipi_Kat Kaloriferi                       -0.003119   0.001799
# Isıtma Tipi_Kombi Doğalgaz                       -0.036965   0.021319
# Isıtma Tipi_Merkezi (Pay Ölçer)                  -0.041282   0.023809
# Isıtma Tipi_Merkezi Doğalgaz                     -0.037508  -0.047953
# Isıtma Tipi_Merkezi Fueloil                      -0.001799   0.001037
# Isıtma Tipi_Sobalı                               -0.008124   0.004686
# Isıtma Tipi_Yerden Isıtma                         1.000000   0.001799
# Takas_Yok                                         0.001799   1.000000
# Lokasyon_Kocasinan                               -0.037780   0.021790
# Lokasyon_Melikgazi                                0.074862   0.024026
# Lokasyon_Talas                                   -0.032041  -0.056135
# Lokasyon_Yeşilhisar                              -0.003603   0.002078
# Lokasyon_İncesu                                  -0.003119   0.001799
# Isıtma_Kategori_Merkezi                          -0.078730  -0.022845
# Isıtma_Kategori_Sobalı                           -0.008329   0.004804
# Isıtma_Kategori_Yerden Isıtma                     1.000000   0.001799
#
#                                  Lokasyon_Kocasinan  Lokasyon_Melikgazi  \
# Net Metrekare                              0.007484            0.123350
# Brüt Metrekare                             0.023468            0.125677
# Binanın Yaşı                               0.067092            0.080736
# Binanın Kat Sayısı                        -0.117486            0.018011
# Eşya Durumu                               -0.054619           -0.071178
# Tapu Durumu                                0.040054           -0.136956
# Site İçerisinde                            0.000223           -0.003742
# Banyo Sayısı                               0.005426            0.097271
# Fiyat                                     -0.014249            0.037798
# Oda                                        0.065521            0.107633
# Salon                                     -0.098837            0.100864
# Kat                                       -0.126270            0.075809
# Tipi_Daire                                 0.053694           -0.083992
# Tipi_Köşk                                 -0.021790           -0.024026
# Tipi_Müstakil Ev                          -0.003084            0.030423
# Tipi_Residence                            -0.048825           -0.023719
# Tipi_Villa                                -0.030580            0.103213
# Isıtma Tipi_Isıtma Yok                     0.047607           -0.024026
# Isıtma Tipi_Kat Kaloriferi                 0.002327           -0.041657
# Isıtma Tipi_Kombi Doğalgaz                 0.046993           -0.038093
# Isıtma Tipi_Merkezi (Pay Ölçer)            0.069735           -0.026741
# Isıtma Tipi_Merkezi Doğalgaz              -0.121549            0.068886
# Isıtma Tipi_Merkezi Fueloil               -0.021790           -0.024026
# Isıtma Tipi_Sobalı                         0.026960           -0.017458
# Isıtma Tipi_Yerden Isıtma                 -0.037780            0.074862
# Takas_Yok                                  0.021790            0.024026
# Lokasyon_Kocasinan                         1.000000           -0.504668
# Lokasyon_Melikgazi                        -0.504668            1.000000
# Lokasyon_Talas                            -0.388171           -0.428001
# Lokasyon_Yeşilhisar                       -0.043648           -0.048126
# Lokasyon_İncesu                           -0.037780           -0.041657
# Isıtma_Kategori_Merkezi                   -0.050067            0.038840
# Isıtma_Kategori_Sobalı                     0.036823           -0.022344
# Isıtma_Kategori_Yerden Isıtma             -0.037780            0.074862
#
#                                  Lokasyon_Talas  Lokasyon_Yeşilhisar  \
# Net Metrekare                         -0.083286            -0.046625
# Brüt Metrekare                        -0.079010            -0.050116
# Binanın Yaşı                          -0.146211             0.129140
# Binanın Kat Sayısı                     0.345388            -0.105566
# Eşya Durumu                            0.156244            -0.018729
# Tapu Durumu                            0.078458             0.010521
# Site İçerisinde                        0.061635            -0.022543
# Banyo Sayısı                          -0.099992            -0.046281
# Fiyat                                 -0.016017            -0.004711
# Oda                                   -0.138143            -0.055303
# Salon                                  0.024938             0.000929
# Kat                                    0.112209            -0.060478
# Tipi_Daire                             0.002565             0.011356
# Tipi_Köşk                              0.056135            -0.002078
# Tipi_Müstakil Ev                      -0.011300            -0.006602
# Tipi_Residence                         0.092344            -0.004656
# Tipi_Villa                            -0.061610            -0.006928
# Isıtma Tipi_Isıtma Yok                -0.018480            -0.002078
# Isıtma Tipi_Kat Kaloriferi             0.054206            -0.003603
# Isıtma Tipi_Kombi Doğalgaz            -0.233746             0.027381
# Isıtma Tipi_Merkezi (Pay Ölçer)        0.083092            -0.047693
# Isıtma Tipi_Merkezi Doğalgaz           0.154041            -0.043333
# Isıtma Tipi_Merkezi Fueloil            0.056135            -0.002078
# Isıtma Tipi_Sobalı                    -0.049768             0.217045
# Isıtma Tipi_Yerden Isıtma             -0.032041            -0.003603
# Takas_Yok                             -0.056135             0.002078
# Lokasyon_Kocasinan                    -0.388171            -0.043648
# Lokasyon_Melikgazi                    -0.428001            -0.048126
# Lokasyon_Talas                         1.000000            -0.037017
# Lokasyon_Yeşilhisar                   -0.037017             1.000000
# Lokasyon_İncesu                       -0.032041            -0.003603
# Isıtma_Kategori_Merkezi                0.239089            -0.090957
# Isıtma_Kategori_Sobalı                -0.052669             0.211468
# Isıtma_Kategori_Yerden Isıtma         -0.032041            -0.003603
#
#                                  Lokasyon_İncesu  Isıtma_Kategori_Merkezi  \
# Net Metrekare                          -0.063372                -0.000219
# Brüt Metrekare                         -0.058923                -0.002738
# Binanın Yaşı                           -0.031906                -0.385111
# Binanın Kat Sayısı                     -0.085915                 0.662615
# Eşya Durumu                            -0.016211                 0.000850
# Tapu Durumu                             0.009107                 0.022562
# Site İçerisinde                         0.040264                 0.099752
# Banyo Sayısı                           -0.040060                 0.147784
# Fiyat                                  -0.004002                 0.016349
# Oda                                    -0.066193                 0.013558
# Salon                                   0.000804                -0.101745
# Kat                                    -0.062474                 0.139558
# Tipi_Daire                              0.009830                 0.145258
# Tipi_Köşk                              -0.001799                -0.045408
# Tipi_Müstakil Ev                       -0.005714                -0.144266
# Tipi_Residence                         -0.004030                 0.051190
# Tipi_Villa                             -0.005996                -0.130700
# Isıtma Tipi_Isıtma Yok                 -0.001799                -0.045408
# Isıtma Tipi_Kat Kaloriferi             -0.003119                -0.078730
# Isıtma Tipi_Kombi Doğalgaz             -0.036965                -0.933208
# Isıtma Tipi_Merkezi (Pay Ölçer)         0.036601                 0.524347
# Isıtma Tipi_Merkezi Doğalgaz            0.002709                 0.476413
# Isıtma Tipi_Merkezi Fueloil            -0.001799                 0.022845
# Isıtma Tipi_Sobalı                     -0.008124                -0.205100
# Isıtma Tipi_Yerden Isıtma              -0.003119                -0.078730
# Takas_Yok                               0.001799                -0.022845
# Lokasyon_Kocasinan                     -0.037780                -0.050067
# Lokasyon_Melikgazi                     -0.041657                 0.038840
# Lokasyon_Talas                         -0.032041                 0.239089
# Lokasyon_Yeşilhisar                    -0.003603                -0.090957
# Lokasyon_İncesu                         1.000000                 0.039610
# Isıtma_Kategori_Merkezi                 0.039610                 1.000000
# Isıtma_Kategori_Sobalı                 -0.008329                -0.210276
# Isıtma_Kategori_Yerden Isıtma          -0.003119                -0.078730
#
#                                  Isıtma_Kategori_Sobalı  \
# Net Metrekare                                 -0.002414
# Brüt Metrekare                                 0.013040
# Binanın Yaşı                                   0.281006
# Binanın Kat Sayısı                            -0.226132
# Eşya Durumu                                   -0.016769
# Tapu Durumu                                   -0.020386
# Site İçerisinde                               -0.052116
# Banyo Sayısı                                  -0.082411
# Fiyat                                          0.030409
# Oda                                           -0.018320
# Salon                                          0.100827
# Kat                                            0.032492
# Tipi_Daire                                    -0.223347
# Tipi_Köşk                                     -0.004804
# Tipi_Müstakil Ev                               0.405543
# Tipi_Residence                                -0.010764
# Tipi_Villa                                    -0.016016
# Isıtma Tipi_Isıtma Yok                         0.215942
# Isıtma Tipi_Kat Kaloriferi                    -0.008329
# Isıtma Tipi_Kombi Doğalgaz                    -0.098727
# Isıtma Tipi_Merkezi (Pay Ölçer)               -0.110258
# Isıtma Tipi_Merkezi Doğalgaz                  -0.100178
# Isıtma Tipi_Merkezi Fueloil                   -0.004804
# Isıtma Tipi_Sobalı                             0.975384
# Isıtma Tipi_Yerden Isıtma                     -0.008329
# Takas_Yok                                      0.004804
# Lokasyon_Kocasinan                             0.036823
# Lokasyon_Melikgazi                            -0.022344
# Lokasyon_Talas                                -0.052669
# Lokasyon_Yeşilhisar                            0.211468
# Lokasyon_İncesu                               -0.008329
# Isıtma_Kategori_Merkezi                       -0.210276
# Isıtma_Kategori_Sobalı                         1.000000
# Isıtma_Kategori_Yerden Isıtma                 -0.008329
#
#                                  Isıtma_Kategori_Yerden Isıtma
# Net Metrekare                                         0.095429
# Brüt Metrekare                                        0.087883
# Binanın Yaşı                                         -0.054896
# Binanın Kat Sayısı                                   -0.042226
# Eşya Durumu                                          -0.016211
# Tapu Durumu                                           0.009107
# Site İçerisinde                                       0.040264
# Banyo Sayısı                                          0.088799
# Fiyat                                                 0.006718
# Oda                                                   0.068180
# Salon                                                 0.000804
# Kat                                                   0.148136
# Tipi_Daire                                           -0.208229
# Tipi_Köşk                                            -0.001799
# Tipi_Müstakil Ev                                     -0.005714
# Tipi_Residence                                       -0.004030
# Tipi_Villa                                            0.344706
# Isıtma Tipi_Isıtma Yok                               -0.001799
# Isıtma Tipi_Kat Kaloriferi                           -0.003119
# Isıtma Tipi_Kombi Doğalgaz                           -0.036965
# Isıtma Tipi_Merkezi (Pay Ölçer)                      -0.041282
# Isıtma Tipi_Merkezi Doğalgaz                         -0.037508
# Isıtma Tipi_Merkezi Fueloil                          -0.001799
# Isıtma Tipi_Sobalı                                   -0.008124
# Isıtma Tipi_Yerden Isıtma                             1.000000
# Takas_Yok                                             0.001799
# Lokasyon_Kocasinan                                   -0.037780
# Lokasyon_Melikgazi                                    0.074862
# Lokasyon_Talas                                       -0.032041
# Lokasyon_Yeşilhisar                                  -0.003603
# Lokasyon_İncesu                                      -0.003119
# Isıtma_Kategori_Merkezi                              -0.078730
# Isıtma_Kategori_Sobalı                               -0.008329
# Isıtma_Kategori_Yerden Isıtma                         1.000000

# %%
def algo_test(x, y):
    # Modellerin tanımlanması
    models = [
        ('Linear Regression', LinearRegression()),
        ('Ridge', Ridge()),
        ('Lasso', Lasso()),
        ('ElasticNet', ElasticNet()),
        ('SGD Regressor', SGDRegressor()),
        ('Extra Tree', ExtraTreeRegressor()),
        ('Gradient Boosting', GradientBoostingRegressor()),
        ('AdaBoost', AdaBoostRegressor()),
        ('KNN', KNeighborsRegressor()),
        ('Decision Tree', DecisionTreeRegressor()),
        ('XGBoost', XGBRegressor()),
        ('SVR', SVR()),
        ('MLP Regressor', MLPRegressor(max_iter=1000))
    ]
    
    # Verinin bölünmesi
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    
    # Ölçeklendirme
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Sonuç DataFrame'i
    results = pd.DataFrame(columns=['Model', 'R2', 'RMSE', 'MAE'])
    
    for name, model in models:
        try:
            # Model eğitimi ve tahmin
            model.fit(X_train_scaled, y_train)
            y_pred = model.predict(X_test_scaled)
            
            # Metrik hesaplamaları
            r2 = round(r2_score(y_test, y_pred), 4)
            rmse = round(np.sqrt(mean_squared_error(y_test, y_pred)), 2)
            mae = round(mean_absolute_error(y_test, y_pred), 2)
            
            # Sonuçların kaydedilmesi
            results = pd.concat([results, pd.DataFrame({
                'Model': [name],
                'R2': [r2],
                'RMSE': [rmse],
                'MAE': [mae]
            })], ignore_index=True)
            
        except Exception as e:
            print(f"{name} modelinde hata oluştu: {str(e)}")
    
    return results.sort_values('R2', ascending=False)

# Kullanım örneği
X = df.drop('Fiyat', axis=1)
y = df['Fiyat']

categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
X_processed = pd.get_dummies(X, columns=categorical_cols)

# Algoritma testinin çalıştırılması
performance_results = algo_test(X_processed, y)

# Sonuçların gösterilmesi
print("="*60)
print("MODEL PERFORMANS KARŞILAŞTIRMASI")
print("="*60)
print(performance_results.to_string(index=False))
# Out:
# ============================================================
# MODEL PERFORMANS KARŞILAŞTIRMASI
# ============================================================
#             Model         R2      RMSE      MAE
#        Extra Tree     0.7489   4223.80  2773.58
#          AdaBoost     0.2019   7529.73  3734.92
#               SVR    -0.0307   8556.57  4116.72
#     MLP Regressor    -1.3890  13027.24 10718.42
#        ElasticNet   -99.8273  84631.08 30806.32
#     SGD Regressor  -129.0766  96125.90 42410.33
#     Decision Tree  -148.9947 103223.54 12732.90
# Gradient Boosting  -243.8439 131881.96 15623.71
#             Ridge  -257.6084 135538.31 51374.49
#             Lasso  -259.4995 136032.99 51548.62
# Linear Regression  -259.5208 136038.54 51551.42
#               KNN  -507.3589 190031.68 28520.47
#           XGBoost -4045.6913 536155.57 42944.25

# %% [markdown]
# ## Sonuçlar
# En iyi sonuçları elde ettiğimiz model, **Extra Tree Regressor** oldu:
# - **R²**: 0.7489
# - **RMSE**: 4223.80
# - **MAE**: 2773.58
#
# Bu sonuçlar, modelimizin Kayseri ev fiyatlarını tahmin etmede daha fazla iyileştirme yapılması gerektiğini ortaya koymaktadır.
